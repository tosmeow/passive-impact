# %%
from plot_utils import *

path_with, path_without, queue_with, queue_without = load_data()

# %%
plot_queue_shades(path_with, sim_col = 'sim', title = 'Impact given q', label = 'Price impact', ref_col = None)

# %%
plot_queue_shades(queue_with, sim_col = 'bar_q', title = 'Queue_bar given q', label = 'Queue size', ref_col = 'q')

# %%
plot_queue_shades(path_without, sim_col = 'sim', title = 'Impact given q_bar', label = 'Price impact', ref_col = None)

# %%
plot_queue_shades(queue_without, sim_col = 'q', title = 'Queue given q_bar', label = 'Queue size', ref_col = 'bar_q')
