# %%
import pandas as pd
import matplotlib.pyplot as plt

dist = -pd.read_csv('impact_paths.csv').set_index('time')

# %%
dist.plot(legend=False)

# %%
y = dist.mean(axis=1)
y = y[y != 0]

# %%
x = pd.Series(y.index, index=y.index)

# %%
dist.std(axis=1).plot()

# %%
y.plot()
