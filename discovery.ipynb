# %%
import pandas as pd
import matplotlib.pyplot as plt

dist = pd.read_csv('impact_paths.csv').set_index('time')
dist_wo = pd.read_csv('impact_paths_without.csv').set_index('time')

# %%
dist.plot(legend=False)
# Out:
# <Axes: xlabel='time'>

# %%
dist_wo.plot(legend=False)
# Out:
# <Axes: xlabel='time'>

# %%
queues = pd.read_csv('queue_paths.csv').set_index('time')
queues_without = pd.read_csv('queue_paths_without.csv').set_index('time')

# %%
queues.plot(legend=False)
# Out:
# <Axes: xlabel='time'>

# %%
queues_without.plot(legend=False)
# Out:
# <Axes: xlabel='time'>
