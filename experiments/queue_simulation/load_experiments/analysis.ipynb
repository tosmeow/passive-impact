# %% [markdown]
# # Queue Simulation — counterfactual queue paths
#
# Loads pre-saved baseline data from `./data/{single,double}/{efficient,general}/` and renders queue-shade plots.

# %%
from plot_utils import load_data, plot_queue_shades
df = load_data(mode='single', data_mode='efficient')
plot_queue_shades(df, meta_end=80.0)
